# %% [markdown]
# <a href="https://colab.research.google.com/github/Harin22/data-wrangling-visualization/blob/main/Data_transformation_(in_depth).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
new_df = pd.read_csv("final_cleared_data.csv")
display(new_df)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1458  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1459  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1460  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1461  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1462  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
new_df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# This project showcases essential data preprocessing, transformation, and visualization skills

# %% [markdown]
# **Scaling Numeric Data from the**

# %% [markdown]
# we use min-max scaling method to keep values between 0 to 1 for better visualization and interpretation

# %%
#from sklearn.preprocessing import MinMaxScaler

#scaler = MinMaxScaler    #min-max scaling methoid
#new_df[numeric_cols] = scaler.fit_transform(new_df[numeric_cols])

#display(new_df[numeric_cols])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
numeric_cols = ['actual_price', 'discounted_price' ]

new_df[numeric_cols] = scaler.fit_transform(new_df[numeric_cols])
display(new_df[numeric_cols])
# Out:
#       actual_price  discounted_price
# 0         0.012476          0.005810
# 1         0.003649          0.002582
# 2         0.021892          0.002582
# 3         0.007768          0.004680
# 4         0.004237          0.001856
# ...            ...               ...
# 1458      0.010358          0.005487
# 1459      0.035381          0.036168
# 1460      0.035793          0.035184
# 1461      0.021786          0.021950
# 1462      0.042973          0.045578
#
# [1463 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()  #applying standardization
new_df[['rating', 'rating_count']] = scaler.fit_transform(new_df[['rating','rating_count']])

display(new_df[['rating', 'rating_count']])
# Out:
#         rating  rating_count
# 0     0.356494      0.003515
# 1    -0.330209      0.003515
# 2    -0.673560      0.003515
# 3     0.356494      0.003515
# 4     0.356494      0.003515
# ...        ...           ...
# 1458 -0.330209      0.003515
# 1459  0.013143      0.003515
# 1460 -1.703614      0.960185
# 1461 -0.330209      0.003515
# 1462  0.699845      0.003515
#
# [1463 rows x 2 columns]

# %%
display(new_df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...          0.005810
# 1  Computers&Accessories|Accessories&Peripherals|...          0.002582
# 2  Computers&Accessories|Accessories&Peripherals|...          0.002582
# 3  Computers&Accessories|Accessories&Peripherals|...          0.004680
# 4  Computers&Accessories|Accessories&Peripherals|...          0.001856
#
#    actual_price  discount_percentage    rating  rating_count  \
# 0      0.012476                   64  0.356494      0.003515
# ...

# %% [markdown]
# **Feature engineering**

# %%
new_df['final_price'] = new_df['actual_price'] - new_df['discounted_price']
display(new_df['final_price'])
# Out:
# 0       0.006666
# 1       0.001066
# 2       0.019310
# 3       0.003088
# 4       0.002381
#           ...
# 1458    0.004870
# 1459   -0.000788
# 1460    0.000609
# 1461   -0.000163
# 1462   -0.002605
# Name: final_price, Length: 1463, dtype: float64

# %% [markdown]
# checking if the operation is done correctly on the scaled data.

# %%
new_df['scaled_actual_price'] = new_df['actual_price']
new_df['scaled_discounted_price'] = new_df['discounted_price']


new_df['final_price'] = new_df['scaled_actual_price'] - new_df['scaled_discounted_price']
display(new_df['final_price'])
# Out:
# 0       0.006666
# 1       0.001066
# 2       0.019310
# 3       0.003088
# 4       0.002381
#           ...
# 1458    0.004870
# 1459   -0.000788
# 1460    0.000609
# 1461   -0.000163
# 1462   -0.002605
# Name: final_price, Length: 1463, dtype: float64

# %%
#doublechecking column
print(new_df[['actual_price', 'discounted_price']].describe())
print(new_df[['scaled_actual_price', 'scaled_discounted_price']].describe())
# Out:
#        actual_price  discounted_price
# count   1463.000000       1463.000000
# mean       0.062571          0.048997
# std        0.121206          0.107606
# min        0.000000          0.000000
# 25%        0.008957          0.004576
# 50%        0.018962          0.012266
# 75%        0.050094          0.031633
# max        1.000000          1.000000
#        scaled_actual_price  scaled_discounted_price
# count          1463.000000              1463.000000
# mean              0.062571                 0.048997
# std               0.121206                 0.107606
# min               0.000000                 0.000000
# 25%               0.008957                 0.004576
# 50%               0.018962                 0.012266
# 75%               0.050094                 0.031633
# max               1.000000                 1.000000

# %%
#check discount and applying binaryfeatures
new_df['has_discount'] = (new_df['discount_percentage'] > 0).astype(int)
display(new_df['has_discount'])
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1458    1
# 1459    1
# 1460    1
# 1461    1
# 1462    1
# Name: has_discount, Length: 1463, dtype: int64

# %%
display(new_df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...          0.005810
# 1  Computers&Accessories|Accessories&Peripherals|...          0.002582
# 2  Computers&Accessories|Accessories&Peripherals|...          0.002582
# 3  Computers&Accessories|Accessories&Peripherals|...          0.004680
# 4  Computers&Accessories|Accessories&Peripherals|...          0.001856
#
#    actual_price  discount_percentage    rating  rating_count  \
# 0      0.012476                   64  0.356494      0.003515
# ...

# %%
print("Final Data Summary")
display(new_df.describe())

#saved teh dataset
new_df.to_csv("Data_after_DT.csv", index=False)
# Out:
# Final Data Summary
#        discounted_price  actual_price  discount_percentage        rating  \
# count       1463.000000   1463.000000          1463.000000  1.463000e+03
# mean           0.048997      0.062571            47.715653  8.402180e-16
# std            0.107606      0.121206            21.634599  1.000342e+00
# min            0.000000      0.000000             0.000000 -7.197236e+00
# 25%            0.004576      0.008957            32.000000 -3.302087e-01
# 50%            0.012266      0.018962            50.000000  1.314264e-02
# 75%            0.031633      0.050094            63.000000  6.998454e-01
# max            1.000000      1.000000            94.000000  3.103305e+00
#
#        rating_count  final_price  scaled_actual_price  \
# count  1.463000e+03  1463.000000          1463.000000
# mean  -1.202046e-16     0.013574             0.062571
# std    1.000342e+00     0.035382             0.121206
# min   -2.761639e+00    -0.176563             0.000000
# ...
